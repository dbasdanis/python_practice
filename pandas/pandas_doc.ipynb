# %% [markdown]
# # Using Pandas

# %% [markdown]
# ### Importing pandas

# %%
import pandas

# %%
pandas.__version__
# Out:
# '1.5.3'

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.5.3'

# %% [markdown]
# # Series and DataFrames

# %%
import pandas as pd

oo = pd.read_csv('./data/olympics.csv', skiprows=4)
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %% [markdown]
# ### Accessing the DataFrame

# %%
oo
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 0       Athens     1896   Aquatics         Swimming         HAJOS, Alfred
# 1       Athens     1896   Aquatics         Swimming      HERSCHMANN, Otto
# 2       Athens     1896   Aquatics         Swimming     DRIVAS, Dimitrios
# 3       Athens     1896   Aquatics         Swimming    MALOKINIS, Ioannis
# 4       Athens     1896   Aquatics         Swimming    CHASAPIS, Spiridon
# ...        ...      ...        ...              ...                   ...
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender                       Event Event_gender   Medal
# ...

# %% [markdown]
# ## Series
# A Series is a one-dimensional array of indexed data.

# %% [markdown]
# ### Accessing Series

# %%
oo.Athlete
# Out:
# 0               HAJOS, Alfred
# 1            HERSCHMANN, Otto
# 2           DRIVAS, Dimitrios
# 3          MALOKINIS, Ioannis
# 4          CHASAPIS, Spiridon
#                  ...
# 29211          ENGLICH, Mirko
# 29212    MIZGAITIS, Mindaugas
# 29213         PATRIKEEV, Yuri
# 29214           LOPEZ, Mijain
# 29215          BAROEV, Khasan
# Name: Athlete, Length: 29216, dtype: object

# %%
oo[['City','Edition','Athlete']]
# Out:
#           City  Edition               Athlete
# 0       Athens     1896         HAJOS, Alfred
# 1       Athens     1896      HERSCHMANN, Otto
# 2       Athens     1896     DRIVAS, Dimitrios
# 3       Athens     1896    MALOKINIS, Ioannis
# 4       Athens     1896    CHASAPIS, Spiridon
# ...        ...      ...                   ...
# 29211  Beijing     2008        ENGLICH, Mirko
# 29212  Beijing     2008  MIZGAITIS, Mindaugas
# 29213  Beijing     2008       PATRIKEEV, Yuri
# 29214  Beijing     2008         LOPEZ, Mijain
# 29215  Beijing     2008        BAROEV, Khasan
#
# [29216 rows x 3 columns]

# %%
type(oo)
# Out:
# pandas.core.frame.DataFrame

# %%
type(oo.City)
# Out:
# pandas.core.series.Series

# %%
type(oo[['City','Edition','Athlete']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### List our Olympics DataFrame

# %%
oo
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 0       Athens     1896   Aquatics         Swimming         HAJOS, Alfred
# 1       Athens     1896   Aquatics         Swimming      HERSCHMANN, Otto
# 2       Athens     1896   Aquatics         Swimming     DRIVAS, Dimitrios
# 3       Athens     1896   Aquatics         Swimming    MALOKINIS, Ioannis
# 4       Athens     1896   Aquatics         Swimming    CHASAPIS, Spiridon
# ...        ...      ...        ...              ...                   ...
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender                       Event Event_gender   Medal
# ...

# %% [markdown]
# ### List only the NOC column

# %%
oo['NOC']
# Out:
# 0        HUN
# 1        AUT
# 2        GRE
# 3        GRE
# 4        GRE
#         ...
# 29211    GER
# 29212    LTU
# 29213    ARM
# 29214    CUB
# 29215    RUS
# Name: NOC, Length: 29216, dtype: object

# %%
oo.NOC
# Out:
# 0        HUN
# 1        AUT
# 2        GRE
# 3        GRE
# 4        GRE
#         ...
# 29211    GER
# 29212    LTU
# 29213    ARM
# 29214    CUB
# 29215    RUS
# Name: NOC, Length: 29216, dtype: object

# %% [markdown]
# ### Determine what type this object is

# %%
type(oo.NOC)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### List Edition, City, Athlete and Medal columns

# %%
oo[['Edition','City','Athlete','Medal']]
# Out:
#        Edition     City               Athlete   Medal
# 0         1896   Athens         HAJOS, Alfred    Gold
# 1         1896   Athens      HERSCHMANN, Otto  Silver
# 2         1896   Athens     DRIVAS, Dimitrios  Bronze
# 3         1896   Athens    MALOKINIS, Ioannis    Gold
# 4         1896   Athens    CHASAPIS, Spiridon  Silver
# ...        ...      ...                   ...     ...
# 29211     2008  Beijing        ENGLICH, Mirko  Silver
# 29212     2008  Beijing  MIZGAITIS, Mindaugas  Bronze
# 29213     2008  Beijing       PATRIKEEV, Yuri  Bronze
# 29214     2008  Beijing         LOPEZ, Mijain    Gold
# 29215     2008  Beijing        BAROEV, Khasan  Silver
#
# [29216 rows x 4 columns]

# %% [markdown]
# # Data Input and Validation

# %%
import pandas as pd

# %%
oo = pd.read_csv('./data/olympics.csv',skiprows=4)

# %%
oo
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 0       Athens     1896   Aquatics         Swimming         HAJOS, Alfred
# 1       Athens     1896   Aquatics         Swimming      HERSCHMANN, Otto
# 2       Athens     1896   Aquatics         Swimming     DRIVAS, Dimitrios
# 3       Athens     1896   Aquatics         Swimming    MALOKINIS, Ioannis
# 4       Athens     1896   Aquatics         Swimming    CHASAPIS, Spiridon
# ...        ...      ...        ...              ...                   ...
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender                       Event Event_gender   Medal
# ...

# %% [markdown]
# ### Overview and validation data
#
# Shape

# %%
oo.shape
# Out:
# (29216, 10)

# %%
oo.head(3)
# Out:
#      City  Edition     Sport Discipline            Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming      HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming   HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming  DRIVAS, Dimitrios  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze

# %%
oo.tail()
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender       Event Event_gender   Medal
# 29211  GER    Men   84 - 96kg            M  Silver
# 29212  LTU    Men  96 - 120kg            M  Bronze
# 29213  ARM    Men  96 - 120kg            M  Bronze
# 29214  CUB    Men  96 - 120kg            M    Gold
# 29215  RUS    Men  96 - 120kg            M  Silver

# %%
oo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29216 entries, 0 to 29215
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   City          29216 non-null  object
#  1   Edition       29216 non-null  int64
#  2   Sport         29216 non-null  object
#  3   Discipline    29216 non-null  object
#  4   Athlete       29216 non-null  object
#  5   NOC           29216 non-null  object
#  6   Gender        29216 non-null  object
#  7   Event         29216 non-null  object
#  8   Event_gender  29216 non-null  object
#  9   Medal         29216 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 2.2+ MB

# %% [markdown]
# # Basic Analysis

# %% [markdown]
# ### value_counts()

# %%
oo.Edition.value_counts()
# Out:
# 2008    2042
# 2000    2015
# 2004    1998
# 1996    1859
# 1992    1705
# 1988    1546
# 1984    1459
# 1980    1387
# 1976    1305
# 1920    1298
# 1972    1185
# 1968    1031
# 1964    1010
# 1952     889
# 1912     885
# 1956     885
# 1924     884
# 1960     882
# 1936     875
# 1948     814
# 1908     804
# 1928     710
# 1932     615
# 1900     512
# 1904     470
# 1896     151
# Name: Edition, dtype: int64

# %%
oo.Gender.value_counts()
# Out:
# Men      21721
# Women     7495
# Name: Gender, dtype: int64

# %%
oo.Gender.value_counts(ascending=True)
# Out:
# Women     7495
# Men      21721
# Name: Gender, dtype: int64

# %% [markdown]
# ### sorted_values()

# %%
ath = oo.Athlete.sort_values()
ath
# Out:
# 651                 AABYE, Edgar
# 2849       AALTONEN, Arvo Ossian
# 2852       AALTONEN, Arvo Ossian
# 7716    AALTONEN, Paavo Johannes
# 7730    AALTONEN, Paavo Johannes
#                   ...
# 603                   ÖSTMO, Ole
# 608                   ÖSTMO, Ole
# 621                   ÖSTMO, Ole
# 596                   ÖSTMO, Ole
# 8051           ÖSTRAND, Per-Olof
# Name: Athlete, Length: 29216, dtype: object

# %%
oo.sort_values(by=['Edition','Athlete'])
# Out:
#           City  Edition       Sport    Discipline  \
# 7       Athens     1896    Aquatics      Swimming
# 82      Athens     1896  Gymnastics   Artistic G.
# 110     Athens     1896  Gymnastics   Artistic G.
# 111     Athens     1896  Gymnastics   Artistic G.
# 48      Athens     1896     Cycling  Cycling Road
# ...        ...      ...         ...           ...
# 28095  Beijing     2008  Equestrian      Dressage
# 28819  Beijing     2008     Sailing       Sailing
# 28977  Beijing     2008   Taekwondo     Taekwondo
# 28387  Beijing     2008  Gymnastics   Rhythmic G.
# 29007  Beijing     2008      Tennis        Tennis
#
#                               Athlete  NOC Gender                 Event  \
# 7                    ANDREOU, Joannis  GRE    Men       1200m freestyle
# 82           ANDRIAKOPOULOS, Nicolaos  GRE    Men         rope climbing
# 110          ANDRIAKOPOULOS, Nicolaos  GRE    Men   team, parallel bars
# ...

# %% [markdown]
# ### Boolean indexing

# %%
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
oo[oo.Medal == 'Gold']
# Out:
#           City  Edition      Sport       Discipline              Athlete  NOC  \
# 0       Athens     1896   Aquatics         Swimming        HAJOS, Alfred  HUN
# 3       Athens     1896   Aquatics         Swimming   MALOKINIS, Ioannis  GRE
# 6       Athens     1896   Aquatics         Swimming        HAJOS, Alfred  HUN
# 9       Athens     1896   Aquatics         Swimming        NEUMANN, Paul  AUT
# 13      Athens     1896  Athletics        Athletics        BURKE, Thomas  USA
# ...        ...      ...        ...              ...                  ...  ...
# 29199  Beijing     2008  Wrestling  Wrestling Gre-R       GUENOT, Steeve  FRA
# 29203  Beijing     2008  Wrestling  Wrestling Gre-R  KVIRKELIA, Manuchar  GEO
# 29206  Beijing     2008  Wrestling  Wrestling Gre-R     MINGUZZI, Andrea  ITA
# 29210  Beijing     2008  Wrestling  Wrestling Gre-R   KHUSHTOV, Aslanbek  RUS
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R        LOPEZ, Mijain  CUB
#
# ...

# %%
oo[(oo.Medal == 'Gold') & (oo.Gender == 'Women')]
# Out:
#            City  Edition          Sport       Discipline  \
# 417       Paris     1900           Golf             Golf
# 641       Paris     1900         Tennis           Tennis
# 649       Paris     1900         Tennis           Tennis
# 710    St Louis     1904        Archery          Archery
# 713    St Louis     1904        Archery          Archery
# ...         ...      ...            ...              ...
# 29134   Beijing     2008  Weightlifting    Weightlifting
# 29147   Beijing     2008      Wrestling  Wrestling Free.
# 29155   Beijing     2008      Wrestling  Wrestling Free.
# 29163   Beijing     2008      Wrestling  Wrestling Free.
# 29171   Beijing     2008      Wrestling  Wrestling Free.
#
#                      Athlete  NOC Gender  \
# 417    ABBOTT, Margaret Ives  USA  Women
# 641        COOPER, Charlotte  GBR  Women
# 649        COOPER, Charlotte  GBR  Women
# 710    HOWELL, Matilda Scott  USA  Women
# 713    HOWELL, Matilda Scott  USA  Women
# ...

# %% [markdown]
# ### String Handling

# %%
oo[oo.Athlete.str.contains('Florence')]
# Out:
#                         City  Edition      Sport      Discipline  \
# 1843                  London     1908    Skating  Figure skating
# 1848                  London     1908    Skating  Figure skating
# 4173                   Paris     1924   Aquatics        Swimming
# 8162                Helsinki     1952  Athletics       Athletics
# 9060   Melbourne / Stockholm     1956  Athletics       Athletics
# 10849                  Tokyo     1964  Athletics       Athletics
# 16817            Los Angeles     1984  Athletics       Athletics
# 18287                  Seoul     1988  Athletics       Athletics
# 18305                  Seoul     1988  Athletics       Athletics
# 18347                  Seoul     1988  Athletics       Athletics
# 18374                  Seoul     1988  Athletics       Athletics
#
#                                Athlete  NOC Gender                   Event  \
# 1843                   SYERS, Florence  GBR  Women              individual
# ...

# %% [markdown]
# ### Challenge

# %%
# in which events did Jesse Owens win a medal?

jo = oo[oo.Athlete == 'OWENS, Jesse']
jo.Event.value_counts()
# Out:
# 100m            1
# 200m            1
# 4x100m relay    1
# long jump       1
# Name: Event, dtype: int64

# %%
# Which country has won the most men's gold medals in singles badminton over the years?
# show the results alphabetically by the player's names.

gbm = oo[(oo.Medal == 'Gold') & (oo.Gender == 'Men') & (oo.Sport == 'Badminton')]
gbm.sort_values(by = ['Athlete'])
# Out:
#             City  Edition      Sport Discipline                  Athlete  NOC  \
# 20045  Barcelona     1992  Badminton  Badminton        BUDI KUSUMA, Alan  INA
# 23701     Sydney     2000  Badminton  Badminton            GUNAWAN, Tony  INA
# 25718     Athens     2004  Badminton  Badminton             HA, Tae-Kwon  KOR
# 25734     Athens     2004  Badminton  Badminton          HIDAYAT, Taufik  INA
# 21787    Atlanta     1996  Badminton  Badminton  HOYER-LARSEN, Poul Erik  DEN
# 23717     Sydney     2000  Badminton  Badminton              JI, Xinpeng  CHN
# 27725    Beijing     2008  Badminton  Badminton             KIDO, Markis  INA
# 25719     Athens     2004  Badminton  Badminton           KIM, Dong Moon  KOR
# 21773    Atlanta     1996  Badminton  Badminton           KIM, Dong Moon  KOR
# 20031  Barcelona     1992  Badminton  Badminton            KIM, Moon-Soo  KOR
# 27727    Beijing     2008  Badminton  Badminton             LEE, Yongdae  KOR
# ...

# %%
# Which three countries have won the most medals in recent years (1984 - 2008)?

rec = oo[oo.Edition >= 1984]
rec.NOC.value_counts().head(3)
# Out:
# USA    1837
# AUS     762
# GER     691
# Name: NOC, dtype: int64

# %%
# Display the male gold medal winners for the 100m Track & Field sprint event over the years.
# List the results starting with the most recent. Show the Olympic City, Edition, Athlete, and the country they represent.

gmh = oo[(oo.Gender=='Men')&(oo.Medal=='Gold')&(oo.Event=='100m')]
gmh.sort_values('Edition',ascending=False)[['City','Edition','Athlete','NOC']]
# Out:
#                         City  Edition                Athlete  NOC
# 27552                Beijing     2008            BOLT, Usain  JAM
# 25539                 Athens     2004         GATLIN, Justin  USA
# 23521                 Sydney     2000        GREENE, Maurice  USA
# 21598                Atlanta     1996        BAILEY, Donovan  CAN
# 19859              Barcelona     1992      CHRISTIE, Linford  GBR
# 18284                  Seoul     1988            LEWIS, Carl  USA
# 16794            Los Angeles     1984            LEWIS, Carl  USA
# 15374                 Moscow     1980           WELLS, Allan  GBR
# 14069               Montreal     1976       CRAWFORD, Hasely  TRI
# 12902                 Munich     1972         BORZOV, Valery  URS
# 11865                 Mexico     1968       HINES, James Ray  USA
# 10823                  Tokyo     1964          HAYES, Robert  USA
# 9924                    Rome     1960            HARY, Armin  EUA
# ...

# %% [markdown]
# # Basic Plotting

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fo = oo[oo.Edition==1984]
fo
# Out:
#               City  Edition      Sport       Discipline  \
# 16592  Los Angeles     1984   Aquatics           Diving
# 16593  Los Angeles     1984   Aquatics           Diving
# 16594  Los Angeles     1984   Aquatics           Diving
# 16595  Los Angeles     1984   Aquatics           Diving
# 16596  Los Angeles     1984   Aquatics           Diving
# ...            ...      ...        ...              ...
# 18046  Los Angeles     1984  Wrestling  Wrestling Gre-R
# 18047  Los Angeles     1984  Wrestling  Wrestling Gre-R
# 18048  Los Angeles     1984  Wrestling  Wrestling Gre-R
# 18049  Los Angeles     1984  Wrestling  Wrestling Gre-R
# 18050  Los Angeles     1984  Wrestling  Wrestling Gre-R
#
#                            Athlete  NOC Gender                          Event  \
# 16592               LI, Kong-Zheng  CHN    Men                   10m platform
# 16593            LOUGANIS, Gregory  USA    Men                   10m platform
# ...

# %% [markdown]
# ## Plot Types:

# %% [markdown]
# ### Line plot

# %%
fo.Sport.value_counts().plot(kind='line');

# %% [markdown]
# ### Bar plot

# %%
fo.Sport.value_counts().plot(kind='bar');

# %% [markdown]
# ### Horisontal plot

# %%
fo.Sport.value_counts().plot(kind='barh');

# %% [markdown]
# ### Pie plot

# %%
fo.Sport.value_counts().plot(kind='pie');

# %% [markdown]
# ## Colors:

# %%
fo.Sport.value_counts().plot(color='plum');

# %%
fo.Sport.value_counts().plot(kind='bar',color='maroon');

# %% [markdown]
# ### figsize()

# %%
fo.Sport.value_counts().plot(figsize=(10,3));

# %% [markdown]
# ## Colormaps

# %%
fo.Sport.value_counts().plot(kind='pie',colormap='Pastel1');

# %% [markdown]
# ## Seaborn basic plotting

# %%
import seaborn as sns

# %%
# How many medals have been won by men and women in the history of the Olympics. How many gold,silver and bronze
# medals won for each gender?

sns.countplot(x='Medal',data=oo, hue='Gender');

# %% [markdown]
# ## Challenge

# %% [markdown]
# Plot the number of medals achieved by the Chinese team (men and women) in Beijing 2008 using:
# * matplotlib
# * seaborn

# %%
mw = oo[(oo.Edition==2008)&(oo.NOC=='CHN')]
mw
# Out:
#           City  Edition          Sport       Discipline           Athlete  \
# 27176  Beijing     2008       Aquatics           Diving       ZHOU, Luxin
# 27177  Beijing     2008       Aquatics           Diving         WANG, Xin
# 27178  Beijing     2008       Aquatics           Diving      CHEN, Ruolin
# 27180  Beijing     2008       Aquatics           Diving          QIN, Kai
# 27181  Beijing     2008       Aquatics           Diving         HE, Chong
# ...        ...      ...            ...              ...               ...
# 29138  Beijing     2008  Weightlifting    Weightlifting        LI, Hongli
# 29140  Beijing     2008  Weightlifting    Weightlifting          LU, Yong
# 29156  Beijing     2008      Wrestling  Wrestling Free.            XU, Li
# 29171  Beijing     2008      Wrestling  Wrestling Free.        WANG, Jiao
# 29204  Beijing     2008      Wrestling  Wrestling Gre-R  CHANG, Yongxiang
#
#        NOC Gender           Event Event_gender   Medal
# ...

# %%
mw.Gender.value_counts().plot(kind='bar');

# %%
sns.countplot(data=oo,x='Gender');

# %% [markdown]
# How can you use colormaps to give the data more meaning?

# %%
sns.countplot(data=oo,x='Gender',palette='bwr');

# %% [markdown]
# Plot the number of Gold, Silver and Bronze medals for each gender.

# %%
sns.countplot(x='Medal',data=mw,hue='Gender');

# %% [markdown]
# How can you give the data more meaning? Is there anything else you can change to make it more intuitive?

# %%
sns.countplot(x='Medal',data=mw,hue='Gender',palette='bwr',order=['Gold','Silver','Bronze']);

# %% [markdown]
# # Indexing
#
# - The index object is an immutable array
# - Indexing allows you to access a row or column using a label

# %%
type(oo.index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %%
oo.index[100]
# Out:
# 100

# %% [markdown]
# ### set_index()

# %%
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
oo.set_index('Athlete')
# Out:
#                          City  Edition      Sport       Discipline  NOC  \
# Athlete
# HAJOS, Alfred          Athens     1896   Aquatics         Swimming  HUN
# HERSCHMANN, Otto       Athens     1896   Aquatics         Swimming  AUT
# DRIVAS, Dimitrios      Athens     1896   Aquatics         Swimming  GRE
# MALOKINIS, Ioannis     Athens     1896   Aquatics         Swimming  GRE
# CHASAPIS, Spiridon     Athens     1896   Aquatics         Swimming  GRE
# ...                       ...      ...        ...              ...  ...
# ENGLICH, Mirko        Beijing     2008  Wrestling  Wrestling Gre-R  GER
# MIZGAITIS, Mindaugas  Beijing     2008  Wrestling  Wrestling Gre-R  LTU
# PATRIKEEV, Yuri       Beijing     2008  Wrestling  Wrestling Gre-R  ARM
# LOPEZ, Mijain         Beijing     2008  Wrestling  Wrestling Gre-R  CUB
# BAROEV, Khasan        Beijing     2008  Wrestling  Wrestling Gre-R  RUS
#
#                      Gender                       Event Event_gender   Medal
# Athlete
# ...

# %%
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
oo.set_index('Athlete')
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
ath = oo
ath
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 0       Athens     1896   Aquatics         Swimming         HAJOS, Alfred
# 1       Athens     1896   Aquatics         Swimming      HERSCHMANN, Otto
# 2       Athens     1896   Aquatics         Swimming     DRIVAS, Dimitrios
# 3       Athens     1896   Aquatics         Swimming    MALOKINIS, Ioannis
# 4       Athens     1896   Aquatics         Swimming    CHASAPIS, Spiridon
# ...        ...      ...        ...              ...                   ...
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender                       Event Event_gender   Medal
# ...

# %% [markdown]
# ### reset_index()

# %%
ath.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
ath.reset_index(inplace=True)
ath.head()
# Out:
#    index    City  Edition     Sport Discipline             Athlete  NOC  \
# 0      0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN
# 1      1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT
# 2      2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE
# 3      3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE
# 4      4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE
#
#   Gender                       Event Event_gender   Medal
# 0    Men              100m freestyle            M    Gold
# 1    Men              100m freestyle            M  Silver
# 2    Men  100m freestyle for sailors            M  Bronze
# 3    Men  100m freestyle for sailors            M    Gold
# 4    Men  100m freestyle for sailors            M  Silver

# %% [markdown]
# ### sort_index()

# %%
ath.set_index('Athlete',inplace=True)
ath.head()
# Out:
#                     index    City  Edition     Sport Discipline  NOC Gender  \
# Athlete
# HAJOS, Alfred           0  Athens     1896  Aquatics   Swimming  HUN    Men
# HERSCHMANN, Otto        1  Athens     1896  Aquatics   Swimming  AUT    Men
# DRIVAS, Dimitrios       2  Athens     1896  Aquatics   Swimming  GRE    Men
# MALOKINIS, Ioannis      3  Athens     1896  Aquatics   Swimming  GRE    Men
# CHASAPIS, Spiridon      4  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                                          Event Event_gender   Medal
# Athlete
# HAJOS, Alfred                   100m freestyle            M    Gold
# HERSCHMANN, Otto                100m freestyle            M  Silver
# DRIVAS, Dimitrios   100m freestyle for sailors            M  Bronze
# MALOKINIS, Ioannis  100m freestyle for sailors            M    Gold
# CHASAPIS, Spiridon  100m freestyle for sailors            M  Silver

# %%
ath.sort_index(inplace=True)
ath.head()
# Out:
#                           index     City  Edition       Sport   Discipline  \
# Athlete
# AABYE, Edgar                651    Paris     1900  Tug of War   Tug of War
# AALTONEN, Arvo Ossian      2849  Antwerp     1920    Aquatics     Swimming
# AALTONEN, Arvo Ossian      2852  Antwerp     1920    Aquatics     Swimming
# AALTONEN, Paavo Johannes   7716   London     1948  Gymnastics  Artistic G.
# AALTONEN, Paavo Johannes   7730   London     1948  Gymnastics  Artistic G.
#
#                           NOC Gender              Event Event_gender   Medal
# Athlete
# AABYE, Edgar              ZZX    Men         tug of war            M    Gold
# AALTONEN, Arvo Ossian     FIN    Men  200m breaststroke            M  Bronze
# AALTONEN, Arvo Ossian     FIN    Men  400m breaststroke            M  Bronze
# AALTONEN, Paavo Johannes  FIN    Men       pommel horse            M    Gold
# AALTONEN, Paavo Johannes  FIN    Men   team competition            M    Gold

# %% [markdown]
# ### loc[...]

# %%
oo.loc['BOLT, Usain']
# Out:
#              index     City  Edition      Sport Discipline  NOC Gender  \
# Athlete
# BOLT, Usain  27570  Beijing     2008  Athletics  Athletics  JAM    Men
# BOLT, Usain  27603  Beijing     2008  Athletics  Athletics  JAM    Men
# BOLT, Usain  27552  Beijing     2008  Athletics  Athletics  JAM    Men
#
#                     Event Event_gender Medal
# Athlete
# BOLT, Usain          200m            M  Gold
# BOLT, Usain  4x100m relay            M  Gold
# BOLT, Usain          100m            M  Gold

# %%
oo.reset_index(inplace=True)

# %%
oo.head()
# Out:
#                     Athlete  index     City  Edition       Sport   Discipline  \
# 0              AABYE, Edgar    651    Paris     1900  Tug of War   Tug of War
# 1     AALTONEN, Arvo Ossian   2849  Antwerp     1920    Aquatics     Swimming
# 2     AALTONEN, Arvo Ossian   2852  Antwerp     1920    Aquatics     Swimming
# 3  AALTONEN, Paavo Johannes   7716   London     1948  Gymnastics  Artistic G.
# 4  AALTONEN, Paavo Johannes   7730   London     1948  Gymnastics  Artistic G.
#
#    NOC Gender              Event Event_gender   Medal
# 0  ZZX    Men         tug of war            M    Gold
# 1  FIN    Men  200m breaststroke            M  Bronze
# 2  FIN    Men  400m breaststroke            M  Bronze
# 3  FIN    Men       pommel horse            M    Gold
# 4  FIN    Men   team competition            M    Gold

# %%
oo.loc[oo.Athlete == 'BOLT, Usain']
# Out:
#           Athlete  index     City  Edition      Sport Discipline  NOC Gender  \
# 2450  BOLT, Usain  27570  Beijing     2008  Athletics  Athletics  JAM    Men
# 2451  BOLT, Usain  27603  Beijing     2008  Athletics  Athletics  JAM    Men
# 2452  BOLT, Usain  27552  Beijing     2008  Athletics  Athletics  JAM    Men
#
#              Event Event_gender Medal
# 2450          200m            M  Gold
# 2451  4x100m relay            M  Gold
# 2452          100m            M  Gold

# %% [markdown]
# ### iloc[]

# %%
oo.head()
# Out:
#                     Athlete  index     City  Edition       Sport   Discipline  \
# 0              AABYE, Edgar    651    Paris     1900  Tug of War   Tug of War
# 1     AALTONEN, Arvo Ossian   2849  Antwerp     1920    Aquatics     Swimming
# 2     AALTONEN, Arvo Ossian   2852  Antwerp     1920    Aquatics     Swimming
# 3  AALTONEN, Paavo Johannes   7716   London     1948  Gymnastics  Artistic G.
# 4  AALTONEN, Paavo Johannes   7730   London     1948  Gymnastics  Artistic G.
#
#    NOC Gender              Event Event_gender   Medal
# 0  ZZX    Men         tug of war            M    Gold
# 1  FIN    Men  200m breaststroke            M  Bronze
# 2  FIN    Men  400m breaststroke            M  Bronze
# 3  FIN    Men       pommel horse            M    Gold
# 4  FIN    Men   team competition            M    Gold

# %%
oo.iloc[1700]
# Out:
# Athlete         BEKKEVOLD, Kristin
# index                        24256
# City                        Sydney
# Edition                       2000
# Sport                     Football
# Discipline                Football
# NOC                            NOR
# Gender                       Women
# Event                     football
# Event_gender                     W
# Medal                         Gold
# Name: 1700, dtype: object

# %%
oo.iloc[[1542,2390,6000,15000]]
# Out:
#                     Athlete  index       City  Edition       Sport  \
# 1542         BAYRAK, Mithat  10666       Rome     1960   Wrestling
# 2390   BOGINSKAYA, Svetlana  18925      Seoul     1988  Gymnastics
# 6000        DORADO, Natalia  20751  Barcelona     1992      Hockey
# 15000      LISITSKY, Viktor  11273      Tokyo     1964  Gymnastics
#
#             Discipline  NOC Gender                     Event Event_gender  \
# 1542   Wrestling Gre-R  TUR    Men  67 - 73kg (welterweight)            M
# 2390       Artistic G.  URS  Women                     vault            W
# 6000            Hockey  ESP  Women                    hockey            W
# 15000      Artistic G.  URS    Men           floor exercises            M
#
#         Medal
# 1542     Gold
# 2390     Gold
# 6000     Gold
# 15000  Silver

# %%
oo.iloc[1:4]
# Out:
#                     Athlete  index     City  Edition       Sport   Discipline  \
# 1     AALTONEN, Arvo Ossian   2849  Antwerp     1920    Aquatics     Swimming
# 2     AALTONEN, Arvo Ossian   2852  Antwerp     1920    Aquatics     Swimming
# 3  AALTONEN, Paavo Johannes   7716   London     1948  Gymnastics  Artistic G.
#
#    NOC Gender              Event Event_gender   Medal
# 1  FIN    Men  200m breaststroke            M  Bronze
# 2  FIN    Men  400m breaststroke            M  Bronze
# 3  FIN    Men       pommel horse            M    Gold

# %% [markdown]
# ## Challenge

# %% [markdown]
# Plot the total number of medals awarded at each of the Olympics games throughout history.

# %%
oo.Edition.value_counts().sort_index().plot()
# Out:
# <Axes: >

# %% [markdown]
# Which countries did not win a medal in the 2008 Olympics? How many countries were there?

# %%
lo = oo[oo.Edition==2008]
lo
# Out:
#                               Athlete  index     City  Edition          Sport  \
# 8                    AAMODT, Ragnhild  28460  Beijing     2008       Handball
# 15                   ABAJO, Jose Luis  28134  Beijing     2008        Fencing
# 16                   ABAKUMOVA, Maria  27691  Beijing     2008      Athletics
# 17                ABALMASAU, Aliaksei  27983  Beijing     2008  Canoe / Kayak
# 18                         ABALO, Luc  28417  Beijing     2008       Handball
# ...                               ...    ...      ...      ...            ...
# 29134  ZU-SAYN WITTGENSTEIN, Nathalie  28095  Beijing     2008     Equestrian
# 29139                  ZUBARI, Shahar  28819  Beijing     2008        Sailing
# 29140                 ZUBCIC, Martina  28977  Beijing     2008      Taekwondo
# 29153                  ZUEVA, Natalia  28387  Beijing     2008     Gymnastics
# 29175                 ZVONAREVA, Vera  29007  Beijing     2008         Tennis
#
# ...

# %%
noc = pd.read_csv('./data/Summer Olympic medallists 1896 to 2008 - IOC COUNTRY CODES.csv')
noc.head()
# Out:
#            Country Int Olympic Committee code ISO code        Country.1
# 0      Afghanistan                        AFG       AF      Afghanistan
# 1          Albania                        ALB       AL          Albania
# 2          Algeria                        ALG       DZ          Algeria
# 3  American Samoa*                        ASA       AS  American Samoa*
# 4          Andorra                        AND       AD          Andorra

# %%
noc[noc['Country'] != noc['Country.1']]
# Out:
# Empty DataFrame
# Columns: [Country, Int Olympic Committee code, ISO code, Country.1]
# Index: []

# %%
noc.set_index('Int Olympic Committee code',inplace=True)
noc.head()
# Out:
#                                     Country ISO code        Country.1
# Int Olympic Committee code
# AFG                             Afghanistan       AF      Afghanistan
# ALB                                 Albania       AL          Albania
# ALG                                 Algeria       DZ          Algeria
# ASA                         American Samoa*       AS  American Samoa*
# AND                                 Andorra       AD          Andorra

# %%
medals_2008=lo.NOC.value_counts()
medals_2008
# Out:
# USA    315
# CHN    184
# AUS    149
# RUS    143
# GER    101
#       ...
# VIE      1
# MDA      1
# VEN      1
# TOG      1
# ISR      1
# Name: NOC, Length: 86, dtype: int64

# %%
noc['medal_2008'] = medals_2008
noc.head()
# Out:
#                                     Country ISO code        Country.1  \
# Int Olympic Committee code
# AFG                             Afghanistan       AF      Afghanistan
# ALB                                 Albania       AL          Albania
# ALG                                 Algeria       DZ          Algeria
# ASA                         American Samoa*       AS  American Samoa*
# AND                                 Andorra       AD          Andorra
#
#                             medal_2008
# Int Olympic Committee code
# AFG                                1.0
# ALB                                NaN
# ALG                                2.0
# ASA                                NaN
# AND                                NaN

# %%
noc[noc.medal_2008.isnull()]
# Out:
#                                         Country ISO code            Country.1  \
# Int Olympic Committee code
# ALB                                     Albania       AL              Albania
# ASA                             American Samoa*       AS      American Samoa*
# AND                                     Andorra       AD              Andorra
# ANG                                      Angola       AO               Angola
# ANT                         Antigua and Barbuda       AG  Antigua and Barbuda
# ...                                         ...      ...                  ...
# URU                                     Uruguay       UY              Uruguay
# VAN                                     Vanuatu       VU              Vanuatu
# ISV                             Virgin Islands*       VI      Virgin Islands*
# YEM                                       Yemen       YE                Yemen
# ZAM                                      Zambia       ZM               Zambia
#
# ...

# %% [markdown]
# # GroupBy

# %%
oo = pd.read_csv('./data/olympics.csv',skiprows=4)
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
oo.groupby('Edition')

# %%
type(oo.groupby('Edition'))
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
list(oo.groupby('Edition'))
# Out:
# [(1896,
#          City  Edition          Sport       Discipline  \
#   0    Athens     1896       Aquatics         Swimming
#   1    Athens     1896       Aquatics         Swimming
#   2    Athens     1896       Aquatics         Swimming
#   3    Athens     1896       Aquatics         Swimming
#   4    Athens     1896       Aquatics         Swimming
#   ..      ...      ...            ...              ...
#   146  Athens     1896  Weightlifting    Weightlifting
#   147  Athens     1896  Weightlifting    Weightlifting
#   148  Athens     1896      Wrestling  Wrestling Gre-R
#   149  Athens     1896      Wrestling  Wrestling Gre-R
#   150  Athens     1896      Wrestling  Wrestling Gre-R
#
#                         Athlete  NOC Gender                        Event  \
#   0               HAJOS, Alfred  HUN    Men               100m freestyle
#   1            HERSCHMANN, Otto  AUT    Men               100m freestyle
# ...

# %% [markdown]
# ### Iterate through a Group

# %%
for group_key, group_value in oo.groupby('Edition'):
    print(group_key)
    print(group_value)
# Out:
# 1896
#        City  Edition          Sport       Discipline  \
# 0    Athens     1896       Aquatics         Swimming
# 1    Athens     1896       Aquatics         Swimming
# 2    Athens     1896       Aquatics         Swimming
# 3    Athens     1896       Aquatics         Swimming
# 4    Athens     1896       Aquatics         Swimming
# ..      ...      ...            ...              ...
# 146  Athens     1896  Weightlifting    Weightlifting
# 147  Athens     1896  Weightlifting    Weightlifting
# 148  Athens     1896      Wrestling  Wrestling Gre-R
# 149  Athens     1896      Wrestling  Wrestling Gre-R
# 150  Athens     1896      Wrestling  Wrestling Gre-R
#
#                       Athlete  NOC Gender                        Event  \
# 0               HAJOS, Alfred  HUN    Men               100m freestyle
# 1            HERSCHMANN, Otto  AUT    Men               100m freestyle
# 2           DRIVAS, Dimitrios  GRE    Men   100m freestyle for sailors
# ...

# %%
type(group_value)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Groupby computations

# %%
oo.groupby('Edition').size()
# Out:
# Edition
# 1896     151
# 1900     512
# 1904     470
# 1908     804
# 1912     885
# 1920    1298
# 1924     884
# 1928     710
# 1932     615
# 1936     875
# 1948     814
# 1952     889
# 1956     885
# 1960     882
# 1964    1010
# 1968    1031
# 1972    1185
# 1976    1305
# 1980    1387
# 1984    1459
# 1988    1546
# 1992    1705
# 1996    1859
# 2000    2015
# 2004    1998
# 2008    2042
# dtype: int64

# %% [markdown]
# ### agg([...])

# %%
oo.groupby(['Edition','NOC','Medal']).agg(['min','max','count'])
# Out:
#                        City                         Sport                 \
#                         min      max count            min            max
# Edition NOC Medal
# 1896    AUS Gold     Athens   Athens     2      Athletics      Athletics
#         AUT Bronze   Athens   Athens     2        Cycling        Cycling
#             Gold     Athens   Athens     2       Aquatics        Cycling
#             Silver   Athens   Athens     1       Aquatics       Aquatics
#         DEN Bronze   Athens   Athens     3        Fencing       Shooting
# ...                     ...      ...   ...            ...            ...
# 2008    UZB Silver  Beijing  Beijing     2           Judo      Wrestling
#         VEN Bronze  Beijing  Beijing     1      Taekwondo      Taekwondo
#         VIE Silver  Beijing  Beijing     1  Weightlifting  Weightlifting
#         ZIM Gold    Beijing  Beijing     1       Aquatics       Aquatics
#             Silver  Beijing  Beijing     3       Aquatics       Aquatics
#
# ...

# %%
oo.groupby(['Edition','NOC','Medal']).size()
# Out:
# Edition  NOC  Medal
# 1896     AUS  Gold      2
#          AUT  Bronze    2
#               Gold      2
#               Silver    1
#          DEN  Bronze    3
#                        ..
# 2008     UZB  Silver    2
#          VEN  Bronze    1
#          VIE  Silver    1
#          ZIM  Gold      1
#               Silver    3
# Length: 2356, dtype: int64

# %%
oo.groupby(['Edition','NOC','Medal']).agg({'Edition':['min','max','count']})
# Out:
#                    Edition
#                        min   max count
# Edition NOC Medal
# 1896    AUS Gold      1896  1896     2
#         AUT Bronze    1896  1896     2
#             Gold      1896  1896     2
#             Silver    1896  1896     1
#         DEN Bronze    1896  1896     3
# ...                    ...   ...   ...
# 2008    UZB Silver    2008  2008     2
#         VEN Bronze    2008  2008     1
#         VIE Silver    2008  2008     1
#         ZIM Gold      2008  2008     1
#             Silver    2008  2008     3
#
# [2356 rows x 3 columns]

# %%
oo.loc[oo.Athlete=='LEWIS, Carl'].groupby('Athlete').agg({'Edition':['min','max','count']})
# Out:
#             Edition
#                 min   max count
# Athlete
# LEWIS, Carl    1984  1996    10

# %% [markdown]
# ### Challenge

# %% [markdown]
# Using groupby(), plot the total number of medals awarded at each of the Olympic games throughout history.

# %%
oo.groupby('Edition').size().plot()
# Out:
# <Axes: xlabel='Edition'>

# %% [markdown]
# Create a list showing the total number of medals won for each country over the hostory of the Olympics. For each country, include the year of
# the first and most recent Olympic medal wins.

# %%
oo.groupby('NOC').agg({'Edition':['count','min','max']})
# Out:
#     Edition
#       count   min   max
# NOC
# AFG       1  2008  2008
# AHO       1  1988  1988
# ALG      14  1984  2008
# ANZ      29  1908  1912
# ARG     239  1924  2008
# ..      ...   ...   ...
# VIE       2  2000  2008
# YUG     435  1924  2000
# ZAM       2  1984  1996
# ZIM      23  1980  2008
# ZZX      48  1896  1904
#
# [138 rows x 3 columns]

# %% [markdown]
# # Reshaping

# %% [markdown]
# ### stack() and unstack()

# %%
mw = oo[(oo.Edition==2008)&((oo.Event=='100m')|(oo.Event=='200m'))]
mw
# Out:
#           City  Edition      Sport Discipline                   Athlete  NOC  \
# 27551  Beijing     2008  Athletics  Athletics               DIX, Walter  USA
# 27552  Beijing     2008  Athletics  Athletics               BOLT, Usain  JAM
# 27553  Beijing     2008  Athletics  Athletics         THOMPSON, Richard  TRI
# 27554  Beijing     2008  Athletics  Athletics        FRASER, Shelly-ann  JAM
# 27555  Beijing     2008  Athletics  Athletics          SIMPSON, Sherone  JAM
# 27556  Beijing     2008  Athletics  Athletics           STEWART, Kerron  JAM
# 27569  Beijing     2008  Athletics  Athletics               DIX, Walter  USA
# 27570  Beijing     2008  Athletics  Athletics               BOLT, Usain  JAM
# 27571  Beijing     2008  Athletics  Athletics           CRAWFORD, Shawn  USA
# 27572  Beijing     2008  Athletics  Athletics           STEWART, Kerron  JAM
# 27573  Beijing     2008  Athletics  Athletics  CAMPBELL-BROWN, Veronica  JAM
# ...

# %%
g = mw.groupby(['NOC','Gender','Discipline','Event']).size()
g
# Out:
# NOC  Gender  Discipline  Event
# JAM  Men     Athletics   100m     1
#                          200m     1
#      Women   Athletics   100m     3
#                          200m     2
# TRI  Men     Athletics   100m     1
# USA  Men     Athletics   100m     1
#                          200m     2
#      Women   Athletics   200m     1
# dtype: int64

# %%
df = g.unstack(['Discipline','Event'])
df
# Out:
# Discipline Athletics
# Event           100m 200m
# NOC Gender
# JAM Men          1.0  1.0
#     Women        3.0  2.0
# TRI Men          1.0  NaN
# USA Men          1.0  2.0
#     Women        NaN  1.0

# %% [markdown]
# ### stack()

# %%
df.stack()
# Out:
# Discipline        Athletics
# NOC Gender Event
# JAM Men    100m         1.0
#            200m         1.0
#     Women  100m         3.0
#            200m         2.0
# TRI Men    100m         1.0
# USA Men    100m         1.0
#            200m         2.0
#     Women  200m         1.0

# %%
df.stack('Event')
# Out:
# Discipline        Athletics
# NOC Gender Event
# JAM Men    100m         1.0
#            200m         1.0
#     Women  100m         3.0
#            200m         2.0
# TRI Men    100m         1.0
# USA Men    100m         1.0
#            200m         2.0
#     Women  200m         1.0

# %% [markdown]
# ### unstack()

# %%
df
# Out:
# Discipline Athletics
# Event           100m 200m
# NOC Gender
# JAM Men          1.0  1.0
#     Women        3.0  2.0
# TRI Men          1.0  NaN
# USA Men          1.0  2.0
#     Women        NaN  1.0

# %%
df.unstack()
# Out:
# Discipline Athletics
# Event           100m       200m
# Gender           Men Women  Men Women
# NOC
# JAM              1.0   3.0  1.0   2.0
# TRI              1.0   NaN  NaN   NaN
# USA              1.0   NaN  2.0   1.0

# %%
df.unstack('Gender')
# Out:
# Discipline Athletics
# Event           100m       200m
# Gender           Men Women  Men Women
# NOC
# JAM              1.0   3.0  1.0   2.0
# TRI              1.0   NaN  NaN   NaN
# USA              1.0   NaN  2.0   1.0

# %% [markdown]
# ### Challenge

# %% [markdown]
# Plot the number of gold medals won by the US male and female athletes throughout the history of Olympics

# %%
gu = oo[(oo.NOC=='USA')&(oo.Medal=='Gold')]
gu.groupby(['Edition','Gender']).size().unstack('Gender',fill_value=0).plot();

# %% [markdown]
# Plot the 5 athletes who have won the most gold medals over the history of the Olympics.
# When there is a tie, consider the number of silver medals, then bronze medals.

# %%
g = oo.groupby(['Athlete','Medal']).size().unstack('Medal',fill_value=0)
g.sort_values(['Gold','Silver','Bronze'],ascending=False)[['Gold','Silver','Bronze']].head(5).plot(kind='bar');

# %% [markdown]
# # Data Visualizations

# %% [markdown]
# ### Seaborn with heatmaps

# %% [markdown]
# Using the Olympic dataset, present a summary of the total medals won by participating countries in the 2008 Olympics.

# %%
lo = oo[oo.Edition == 2008]
lo
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 27174  Beijing     2008   Aquatics           Diving        GALPERIN, Gleb
# 27175  Beijing     2008   Aquatics           Diving      MITCHAM, Matthew
# 27176  Beijing     2008   Aquatics           Diving           ZHOU, Luxin
# 27177  Beijing     2008   Aquatics           Diving             WANG, Xin
# 27178  Beijing     2008   Aquatics           Diving          CHEN, Ruolin
# ...        ...      ...        ...              ...                   ...
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender         Event Event_gender   Medal
# ...

# %%
g = lo.groupby(['NOC','Medal']).size().unstack('Medal',fill_value=0)
g = g.sort_values(['Gold','Silver','Bronze'],ascending=False)[['Gold','Silver','Bronze']]
g.loc['USA',['Gold','Silver','Bronze']]
# Out:
# Medal
# Gold      125
# Silver    109
# Bronze     81
# Name: USA, dtype: int64

# %%
sns.heatmap(g);

# %%
g = g.transpose()
g
# Out:
# NOC     USA  CHN  RUS  GER  KOR  NED  AUS  GBR  FRA  JPN  ...  VIE  ARM  TPE  \
# Medal                                                     ...
# Gold    125   74   43   42   41   40   31   31   25   23  ...    0    0    0
# Silver  109   53   44   16   11   18   42   25   23   11  ...    1    0    0
# Bronze   81   57   56   43   26    4   76   21   28   17  ...    0    6    4
#
# NOC     AFG  EGY  ISR  MDA  MRI  TOG  VEN
# Medal
# Gold      0    0    0    0    0    0    0
# Silver    0    0    0    0    0    0    0
# Bronze    1    1    1    1    1    1    1
#
# [3 rows x 86 columns]

# %%
plt.figure(figsize=(16,5))
sns.heatmap(g);

# %% [markdown]
# ### Create your own Colormap

# %%
g = oo.groupby(['Athlete','Medal']).size().unstack('Medal',fill_value=0)
g.sort_values(['Gold','Silver','Bronze'],ascending=False)[['Gold','Silver','Bronze']].head(5).plot(kind='bar');

# %%
from matplotlib.colors import ListedColormap

# %%
sns.color_palette()
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
gsb = ['#dbb40c','#c5c9c7','#a87900']
sns.color_palette(gsb)
# Out:
# [(0.8588235294117647, 0.7058823529411765, 0.047058823529411764),
#  (0.7725490196078432, 0.788235294117647, 0.7803921568627451),
#  (0.6588235294117647, 0.4745098039215686, 0.0)]

# %%
my_gsb = ListedColormap(sns.color_palette(gsb))

# %%
g = oo.groupby(['Athlete','Medal']).size().unstack('Medal',fill_value=0)
g = g.sort_values(['Gold','Silver','Bronze'],ascending=False)[['Gold','Silver','Bronze']].head(5)
g.plot(kind='bar',colormap=my_gsb);

# %% [markdown]
# # Challenge

# %% [markdown]
# In every Olympics, which US athlete has won the most total number of medals? Include the athlete's discipline.

# %%
gy = oo[oo.NOC=='USA']
gy = gy.groupby(['Edition','Athlete','Medal']).size().unstack('Medal',fill_value=0)[['Gold','Silver','Bronze']]
gy['Total'] = gy['Gold'] + gy['Silver'] + gy['Bronze']
gy.reset_index(inplace=True)
tu = [group.sort_values('Total',ascending=False)[:1] for year,group in gy.groupby('Edition')]
top = pd.DataFrame()
for i in tu:
    top = top.append(i)
top
# Out:
# /var/folders/y4/12q38qbd5hs7h8842l8c6h3m0000gn/T/ipykernel_43027/2050775863.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   top = top.append(i)
# /var/folders/y4/12q38qbd5hs7h8842l8c6h3m0000gn/T/ipykernel_43027/2050775863.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   top = top.append(i)
# /var/folders/y4/12q38qbd5hs7h8842l8c6h3m0000gn/T/ipykernel_43027/2050775863.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   top = top.append(i)
# /var/folders/y4/12q38qbd5hs7h8842l8c6h3m0000gn/T/ipykernel_43027/2050775863.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   top = top.append(i)
# ...
