# %%
import requests
import IPython

# %%
request = requests.get('https://sdo.gsfc.nasa.gov/assets/img/latest/latest_1024_0193.jpg')

# %%
request.ok
# Out:
# True

# %%
IPython.display.Image(data=request.content)
